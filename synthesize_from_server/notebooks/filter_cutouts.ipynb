# %%
import os
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

sys.path.append("../../SemiF-SyntheticPipeline/")
sys.path.append("../../SemiF-AnnotationPipeline/")

from synth_utils.config_utils import read_cutouts, sort_cutouts

# %%
path = "../../SemiF-AnnotationPipeline/data/semifield-cutouts/"
df = read_cutouts(path)
# Out:
# /home/psa_images/Pipeline/SemiF-SyntheticPipeline/synth_utils/config_utils.py:29: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   cutoutsdf = pd.concat([pd.read_csv(x)
# /home/psa_images/Pipeline/SemiF-SyntheticPipeline/synth_utils/config_utils.py:29: DtypeWarning: Columns (102) have mixed types. Specify dtype option on import or set low_memory=False.
#   cutoutsdf = pd.concat([pd.read_csv(x)

# %%
df
# Out:
#        blob_home          data_root       batch_id             image_id  \
# 0           data  semifield-cutouts  MD_2022-08-31        MD_1661948983
# 1           data  semifield-cutouts  MD_2022-08-31        MD_1661948983
# 2           data  semifield-cutouts  MD_2022-08-31        MD_1661948998
# 3           data  semifield-cutouts  MD_2022-08-31        MD_1661948998
# 4           data  semifield-cutouts  MD_2022-08-31        MD_1661949014
# ...          ...                ...            ...                  ...
# 241174      data  semifield-cutouts  NC_2022-07-11  NC_Row-9_1657565686
# 241175      data  semifield-cutouts  NC_2022-07-11  NC_Row-9_1657565705
# 241176      data  semifield-cutouts  NC_2022-07-11  NC_Row-9_1657565705
# 241177      data  semifield-cutouts  NC_2022-07-11  NC_Row-9_1657565705
# 241178      data  semifield-cutouts  NC_2022-07-11  NC_Row-9_1657565705
#
#         cutout_num             datetime  dap              cutout_id  \
# ...
